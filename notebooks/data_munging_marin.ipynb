# %%
import pandas as pd
import numpy as np
import datetime

marin = pd.read_csv('../data/intermediate/Max_Animals_MARIN_data.csv', index_col=0)
marin['Sampling Period'] = marin['Sampling Period'].apply(lambda x: str(x).replace('.', '-'))
marin['Year'] = marin['Sampling Period'].apply(lambda x: x[0:4])

# %%
marin['Sampling Period'] = marin['Sampling Period'].apply(lambda x: 
                                                          datetime.datetime.strptime(x, '%Y-%m'))
marin['Sampling Period'].value_counts()
# Out:
# 2014-10-01    61
# 2014-12-01    59
# 2016-02-01    50
# 2015-01-01    50
# 2016-01-01    49
# 2015-02-01    44
# 2015-12-01    44
# 2014-11-01    42
# 2015-03-01    40
# 2015-11-01    37
# 2015-04-01    36
# 2015-09-01    32
# 2015-06-01    28
# 2016-03-01    28
# 2015-05-01    26
# 2015-08-01    25
# 2014-09-01    24
# 2015-07-01    24
# 2015-10-01    21
# 2016-04-01     1
# dtype: int64

# %%
lat_long = pd.read_csv('../data/intermediate/Marin_Merged.csv', index_col=0)
lat_long = lat_long[['Deployment.Location.ID', 'Latitude.Resolution', 'Longitude.Resolution']] 
lat_long = lat_long.rename(columns = {'Deployment.Location.ID':'Deployment Location ID',
                 'Latitude.Resolution': 'Latitude', 
                 'Longitude.Resolution': 'Longitude'})
lat_long = lat_long.drop_duplicates('Deployment Location ID').reset_index()
del lat_long['index']

# %%
lat_long.head()
# Out:
#   Deployment Location ID   Latitude   Longitude
# 0                   WW64  38.038821 -122.749029
# 1                   XX63  38.043090 -122.743715
# 2                   WW63  38.043094 -122.749595
# 3                   WW65  38.034152 -122.749170
# 4                   XX64  38.038710 -122.743536

# %%
marin = pd.merge(marin, lat_long, on=['Deployment Location ID'], how='left')
marin['Data Source'] = 'MARIN'

# %%
rate = pd.read_csv('../data/intermediate/marin_trap_nights.csv')

rate['Month'] = rate['Month'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m'))

marin = pd.merge(marin, rate, left_on= ['Deployment Location ID', 'Sampling Period'], how = 'inner',
         right_on = ['Deployment.Location.ID', 'Month'])
marin.head()
# Out:
#   Sampling Period Project ID.1 Deployment Location ID       Genus  \
# 0      2014-09-01   ChedaJewel                   WW63     Neotoma
# 1      2014-09-01   ChedaJewel                   WW63  Odocoileus
# 2      2014-09-01   ChedaJewel                   WW63  Peromyscus
# 3      2014-09-01   ChedaJewel                   WW63     Procyon
# 4      2014-09-01   ChedaJewel                   WW63     Sciurus
#
#        Species  Number of Animals  Year   Latitude   Longitude Data Source  \
# 0     fuscipes                  1  2014  38.043094 -122.749595       MARIN
# 1     hemionus                  2  2014  38.043094 -122.749595       MARIN
# 2  maniculatus                  1  2014  38.043094 -122.749595       MARIN
# 3        lotor                  1  2014  38.043094 -122.749595       MARIN
# 4      griseus                  1  2014  38.043094 -122.749595       MARIN
#
#    Unnamed: 0  Project.ID Deployment.Location.ID      Month  Trapnights
# 0           3  ChedaJewel                   WW63 2014-09-01           9
# 1           3  ChedaJewel                   WW63 2014-09-01           9
# 2           3  ChedaJewel                   WW63 2014-09-01           9
# 3           3  ChedaJewel                   WW63 2014-09-01           9
# 4           3  ChedaJewel                   WW63 2014-09-01           9

# %%
marin['Sampling Period'].value_counts()
# Out:
# 2014-10-01    61
# 2014-12-01    59
# 2016-02-01    50
# 2015-01-01    50
# 2016-01-01    49
# 2015-02-01    44
# 2015-12-01    44
# 2014-11-01    42
# 2015-03-01    40
# 2015-11-01    37
# 2015-04-01    36
# 2015-09-01    32
# 2015-06-01    28
# 2016-03-01    28
# 2015-05-01    26
# 2015-08-01    25
# 2014-09-01    24
# 2015-07-01    24
# 2015-10-01    21
# 2016-04-01     1
# dtype: int64

# %%
marin['trap_days_per_100'] = marin['Trapnights']/100.
marin['Rate Of Detection'] = marin['Number of Animals']/marin['trap_days_per_100']
marin['Sampling Period'] = marin['Sampling Period'].apply(lambda x: x.month)
marin['Sampling Type'] = 'Monthly'

# %%
marin['Sampling Period'].value_counts()
# Out:
# 12    103
# 1      99
# 2      94
# 10     82
# 11     79
# 3      68
# 9      56
# 4      37
# 6      28
# 5      26
# 8      25
# 7      24
# dtype: int64

# %%
marin.columns
# Out:
# Index([u'Sampling Period', u'Project ID.1', u'Deployment Location ID',
#        u'Genus', u'Species', u'Number of Animals', u'Year', u'Latitude',
#        u'Longitude', u'Data Source', u'Unnamed: 0', u'Project.ID',
#        u'Deployment.Location.ID', u'Month', u'Trapnights',
#        u'trap_days_per_100', u'Rate Of Detection', u'Sampling Type'],
#       dtype='object')

# %%
marin.rename(columns = {'Latitude' : 'Latitude Resolution',
                        'Longitude' :'Longitude Resolution',
                       'Project.ID' : 'Project ID'}, inplace = True)

marin = marin[['Data Source', 'Project ID', 'Deployment Location ID', 'Latitude Resolution', 'Longitude Resolution', 
'Sampling Type', 'Sampling Period', 'Year', 'Genus', 'Species', 'Rate Of Detection']]

# %%
marin.head(100)
# Out:
#    Data Source  Project ID Deployment Location ID  Latitude Resolution  \
# 0        MARIN  ChedaJewel                   WW63            38.043094
# 1        MARIN  ChedaJewel                   WW63            38.043094
# 2        MARIN  ChedaJewel                   WW63            38.043094
# 3        MARIN  ChedaJewel                   WW63            38.043094
# 4        MARIN  ChedaJewel                   WW63            38.043094
# 5        MARIN  ChedaJewel                   WW64            38.038821
# 6        MARIN  ChedaJewel                   WW64            38.038821
# 7        MARIN  ChedaJewel                   WW65            38.034152
# 8        MARIN  ChedaJewel                   WW65            38.034152
# 9        MARIN  ChedaJewel                   WW65            38.034152
# 10       MARIN  ChedaJewel                   WW65            38.034152
# 11       MARIN  ChedaJewel                   WW66            38.029709
# 12       MARIN  ChedaJewel                   XX63            38.043090
# 13       MARIN  ChedaJewel                   XX63            38.043090
# 14       MARIN  ChedaJewel                   XX63            38.043090
# 15       MARIN  ChedaJewel                   XX63            38.043090
# 16       MARIN  ChedaJewel                   XX63            38.043090
# 17       MARIN  ChedaJewel                   XX64            38.038710
# 18       MARIN  ChedaJewel                   XX64            38.038710
# 19       MARIN  ChedaJewel                   YY63            38.043270
# 20       MARIN  ChedaJewel                   YY63            38.043270
# 21       MARIN  ChedaJewel                   YY64            38.038760
# 22       MARIN  ChedaJewel                   YY64            38.038760
# 23       MARIN  ChedaJewel                   YY64            38.038760
# 24       MARIN  ChedaJewel                   WW63            38.043094
# 25       MARIN  ChedaJewel                   WW63            38.043094
# 26       MARIN  ChedaJewel                   WW63            38.043094
# 27       MARIN  ChedaJewel                   WW63            38.043094
# 28       MARIN  ChedaJewel                   WW63            38.043094
# 29       MARIN  ChedaJewel                   WW63            38.043094
# ..         ...         ...                    ...                  ...
# 70       MARIN  ChedaJewel                   XX64            38.038710
# 71       MARIN  ChedaJewel                   XX64            38.038710
# 72       MARIN  ChedaJewel                   XX64            38.038710
# 73       MARIN  ChedaJewel                   XX64            38.038710
# 74       MARIN  ChedaJewel                   YY63            38.043270
# 75       MARIN  ChedaJewel                   YY63            38.043270
# 76       MARIN  ChedaJewel                   YY63            38.043270
# 77       MARIN  ChedaJewel                   YY63            38.043270
# 78       MARIN  ChedaJewel                   YY63            38.043270
# 79       MARIN  ChedaJewel                   YY64            38.038760
# 80       MARIN  ChedaJewel                   YY64            38.038760
# 81       MARIN  ChedaJewel                   YY64            38.038760
# 82       MARIN  ChedaJewel                   YY64            38.038760
# 83       MARIN  ChedaJewel                   YY64            38.038760
# 84       MARIN  ChedaJewel                   YY64            38.038760
# 85       MARIN  ChedaJewel                   WW63            38.043094
# 86       MARIN  ChedaJewel                   WW63            38.043094
# 87       MARIN  ChedaJewel                   WW63            38.043094
# 88       MARIN  ChedaJewel                   WW63            38.043094
# 89       MARIN  ChedaJewel                   WW63            38.043094
# 90       MARIN  ChedaJewel                   WW63            38.043094
# 91       MARIN  ChedaJewel                   WW63            38.043094
# 92       MARIN  ChedaJewel                   WW65            38.034152
# 93       MARIN  ChedaJewel                   WW65            38.034152
# 94       MARIN  ChedaJewel                   WW65            38.034152
# 95       MARIN  ChedaJewel                   WW65            38.034152
# 96       MARIN  ChedaJewel                   WW65            38.034152
# 97       MARIN  ChedaJewel                   WW65            38.034152
# 98       MARIN  ChedaJewel                   WW66            38.029709
# 99       MARIN  ChedaJewel                   WW66            38.029709
#
#     Longitude Resolution Sampling Type  Sampling Period  Year       Genus  \
# 0            -122.749595       Monthly                9  2014     Neotoma
# 1            -122.749595       Monthly                9  2014  Odocoileus
# 2            -122.749595       Monthly                9  2014  Peromyscus
# 3            -122.749595       Monthly                9  2014     Procyon
# 4            -122.749595       Monthly                9  2014     Sciurus
# 5            -122.749029       Monthly                9  2014  Odocoileus
# 6            -122.749029       Monthly                9  2014     Sciurus
# 7            -122.749170       Monthly                9  2014    Mephitis
# 8            -122.749170       Monthly                9  2014  Odocoileus
# 9            -122.749170       Monthly                9  2014     Sciurus
# 10           -122.749170       Monthly                9  2014     Urocyon
# 11           -122.749492       Monthly                9  2014  Odocoileus
# 12           -122.743715       Monthly                9  2014         Bos
# 13           -122.743715       Monthly                9  2014        Lynx
# 14           -122.743715       Monthly                9  2014    Mephitis
# 15           -122.743715       Monthly                9  2014  Odocoileus
# 16           -122.743715       Monthly                9  2014     Urocyon
# 17           -122.743536       Monthly                9  2014  Odocoileus
# 18           -122.743536       Monthly                9  2014     Sciurus
# 19           -122.738221       Monthly                9  2014        Lynx
# 20           -122.738221       Monthly                9  2014  Odocoileus
# 21           -122.737918       Monthly                9  2014  Odocoileus
# 22           -122.737918       Monthly                9  2014     Procyon
# 23           -122.737918       Monthly                9  2014     Urocyon
# 24           -122.749595       Monthly               10  2014         Bos
# 25           -122.749595       Monthly               10  2014       Canis
# 26           -122.749595       Monthly               10  2014  Cyanocitta
# 27           -122.749595       Monthly               10  2014     Neotoma
# 28           -122.749595       Monthly               10  2014  Odocoileus
# 29           -122.749595       Monthly               10  2014     Procyon
# ..                   ...           ...              ...   ...         ...
# 70           -122.743536       Monthly               10  2014  Odocoileus
# 71           -122.743536       Monthly               10  2014     Procyon
# 72           -122.743536       Monthly               10  2014     Sciurus
# 73           -122.743536       Monthly               10  2014      Tamias
# 74           -122.738221       Monthly               10  2014  Callipepla
# 75           -122.738221       Monthly               10  2014       Canis
# 76           -122.738221       Monthly               10  2014  Odocoileus
# 77           -122.738221       Monthly               10  2014     Procyon
# 78           -122.738221       Monthly               10  2014     Urocyon
# 79           -122.737918       Monthly               10  2014    Catharus
# 80           -122.737918       Monthly               10  2014   Didelphis
# 81           -122.737918       Monthly               10  2014    Mephitis
# 82           -122.737918       Monthly               10  2014  Odocoileus
# 83           -122.737918       Monthly               10  2014     Sciurus
# 84           -122.737918       Monthly               10  2014     Urocyon
# 85           -122.749595       Monthly               11  2014    Colaptes
# 86           -122.749595       Monthly               11  2014     Ixoreus
# 87           -122.749595       Monthly               11  2014        Lynx
# 88           -122.749595       Monthly               11  2014     Neotoma
# 89           -122.749595       Monthly               11  2014  Odocoileus
# 90           -122.749595       Monthly               11  2014     Procyon
# 91           -122.749595       Monthly               11  2014     Sciurus
# 92           -122.749170       Monthly               11  2014     Ixoreus
# 93           -122.749170       Monthly               11  2014        Lynx
# 94           -122.749170       Monthly               11  2014  Odocoileus
# 95           -122.749170       Monthly               11  2014     Procyon
# 96           -122.749170       Monthly               11  2014     Sciurus
# 97           -122.749170       Monthly               11  2014     Urocyon
# 98           -122.749492       Monthly               11  2014        Lynx
# 99           -122.749492       Monthly               11  2014  Odocoileus
#
#              Species  Rate Of Detection
# 0           fuscipes          11.111111
# 1           hemionus          22.222222
# 2        maniculatus          11.111111
# 3              lotor          11.111111
# 4            griseus          11.111111
# 5           hemionus          11.111111
# 6            griseus          11.111111
# 7           mephitis          11.111111
# 8           hemionus          11.111111
# 9            griseus          22.222222
# 10  cinereoargenteus          11.111111
# 11          hemionus          22.222222
# 12            taurus          11.111111
# 13             rufus          11.111111
# 14          mephitis          11.111111
# 15          hemionus          11.111111
# 16  cinereoargenteus          11.111111
# 17          hemionus          11.111111
# 18           griseus          11.111111
# 19             rufus          11.111111
# 20          hemionus          11.111111
# 21          hemionus          14.285714
# 22             lotor          14.285714
# 23  cinereoargenteus          14.285714
# 24            taurus           3.225806
# 25           latrans           3.225806
# 26          stelleri           3.225806
# 27          fuscipes           3.225806
# 28          hemionus           3.225806
# 29             lotor           6.451613
# ..               ...                ...
# 70          hemionus           6.451613
# 71             lotor           3.225806
# 72           griseus           3.225806
# 73           sonomae           3.225806
# 74       californica           4.166667
# 75           latrans           4.166667
# 76          hemionus           4.166667
# 77             lotor           4.166667
# 78  cinereoargenteus           4.166667
# 79          guttatus           3.225806
# 80        virginiana           3.225806
# 81          mephitis           3.225806
# 82          hemionus           6.451613
# 83           griseus           3.225806
# 84  cinereoargenteus           3.225806
# 85           auratus           3.333333
# 86           naevius           3.333333
# 87             rufus           3.333333
# 88          fuscipes           3.333333
# 89          hemionus          10.000000
# 90             lotor           6.666667
# 91           griseus           3.333333
# 92           naevius           3.333333
# 93             rufus           3.333333
# 94          hemionus           6.666667
# 95             lotor           6.666667
# 96           griseus           3.333333
# 97  cinereoargenteus           3.333333
# 98             rufus           3.333333
# 99          hemionus           3.333333
#
# [100 rows x 11 columns]

# %%
marin.to_csv('../data/processed/rate_of_detection_MARIN.csv', index=False)
